# %%
import pandas as pd
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
url='https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=mercedes_benz&models%5B%5D=&maximum_distance=30&zip=%27#vehicle-card-56b8a754-768c-41a3-8a41-b6ceddab36f9'

# %%
def get_page(url):
    driver = webdriver.Chrome()
    driver.get(url)
    driver.implicitly_wait(15)
    page_source = driver.page_source
    soup = BeautifulSoup(page_source,"html.parser")
    return soup

# %%
page=get_page(url)

# %%
soup=get_source_page(url)

# %%
def get_data(url):
    elements=soup.find_all('div', class_='vehicle-card')
    model=[]
    price=[]
    p_mois=[]
    data=[]
    for i in range (len(elements)):
        model= elements[i].find('h2', class_='title').text
        price= elements[i].find('div', class_='price-section price-section-vehicle-card').text
        p_mois_find = elements[i].find('span', class_='estimated-monthly-payments-tooltip js-tooltip-container ')
        if p_mois_find is not None:
            p_mois.append(p_mois_find.text)
        else :
            p_mois.append(None)
    data = {"Model":model,"Price":price,"Prix par mois":p_mois}
    df = pd.DataFrame(data)
    return df

# %%
data=get_data(url)
data
# Out:
#                                       Model                        Price  \
# 0   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 1   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 2   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 3   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 4   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 5   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 6   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 7   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 8   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 9   2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 10  2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# 11  2024 Mercedes-Benz S-Class S 580 4MATIC  \n$141,737\nMSRP $140,540\n
# ...
