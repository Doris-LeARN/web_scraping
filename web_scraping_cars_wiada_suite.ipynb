# %%
from bs4 import BeautifulSoup
#from  selenium import webdriver

import requests
import pandas as pd
from bs4 import BeautifulSoup
import json

import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://www.cars.com/shopping/results/?makes[]=mercedes_benz&maximum_distance=30&models[]=&page=2&stock_type=all&zip=%27"

# %%
def get_soup(url):
    page_source = requests.get(url)
    soup = BeautifulSoup(page_source.content,"html.parser")
    return soup

# %%
soup = get_soup(url)

# %%
all_elt = soup.find_all("div",class_="vehicle-card-main js-gallery-click-card")

# %%
all_elt[0].find("span",class_="sds-rating__count").text
# Out:
# '4.6'

# %%
def get_data(url):
    soup = get_soup(url)
    all_elt = soup.find_all("div",class_="vehicle-card-main js-gallery-click-card")
    titles = []
    prices = []
    #img_links = []
    dealer_names = []
    dealer_phones = []
    infos = []
    trims = []
    makes = []
    customer_ids  = []
    stock_types = []
    listing_ids = []
    model_years = []
    models = []
    sponsoreds = []
    msrps = []
    sponsored_types = []
    pricess = []
    bodystyles = []
    results_page_numbers = []
    cpo_indicators = []
    vertical_positions = [] 
    notes = []
    f = lambda x : x.text.strip("\n") if x else "-"
    g = lambda x : x if x else "-"
    h = lambda x : x["href"].strip("tel:") if x else '-'
    for elt in all_elt:
        title = elt.find("h2",class_="title").text
        price = elt.find("span",class_="primary-price").text
        #img_link = elt.find('img',class_="vehicle-image js-lazy-load styles-lazy-load")["data-src"]
        info = elt.find("a",class_="sds-link")["data-override-payload"]
        dealer_name = elt.find("div",class_="dealer-name")
        dealer_phone = elt.find("div", class_="contact-buttons").find("a", class_="sds-button--secondary contact-by-phone")
        note = elt.find("span",class_="sds-rating__count")
        notes.append(f(note))
        titles.append(title)
        prices.append(price)
        #img_links.append(g(img_link))
        infos.append(info)
        dealer_names.append(f(dealer_name))
        dealer_phones.append(h(dealer_phone))
        info = json.loads(info)
        trims.append(info['trim'])
        makes.append(info['make'])
        customer_ids.append(info['customer_id'])
        stock_types.append(info['stock_type'])
        listing_ids.append(info['listing_id'])
        model_years.append(info['model_year'])
        models.append(info['model'])
        sponsoreds.append(info['sponsored'])
        msrps.append(info[f'msrp'])
        sponsored_types.append(info['sponsored_type'])
        pricess.append(info['price'])
        bodystyles.append(info['bodystyle'])
        results_page_numbers.append(info['results_page_number'])
        cpo_indicators.append(info['cpo_indicator'])
        vertical_positions.append(info['vertical_position'])
        
    data = pd.DataFrame({"Nom":titles,"Prix":prices,"Dealer Phone":dealer_phones,"Dealer Name":dealer_names,"trims":trims,"makes":makes,"customer_ids":customer_ids,"stock_types":stock_types,"model_years" : model_years,"models" : models,"sponsoreds" : sponsoreds,"msrps" : msrps,"sponsored_types": sponsored_types,"prices" : pricess,"bodystyles" : bodystyles,"results_page_numbers" : results_page_numbers,"cpo_indicators" : cpo_indicators,"vertical_positions" : vertical_positions,"Rating":notes})
    return data
#     print(len(titles))
#     print(len(prices))
#     print(len(img_links))
#     print(len(dealer_names))
#     print(len(dealer_phones))
#     print(len(infos ))
#     print(len(trims))
#     print(len(makes))
#     print(len(customer_ids))
#     print(len(stock_types))
#     print(len(listing_ids))
#     print(len(model_years))
#     print(len(models))
#     print(len(sponsoreds))
#     print(len(msrps))
#     print(len(sponsored_types))
#     print(len(prices))
#     print(len(bodystyles))
#     print(len(results_page_numbers))
#     print(len(cpo_indicators))
#     print(len(vertical_positions))

# "Lien":img_links,
                              
#         print(f'Nom : {title}')
#         print(f'Prix : {price}')
#         print(f'Lien :  {img_link}')
#         print(f'Info : {json.loads(info)}')
#         print(f'Dealer name : {dealer_name}')
#         print(f'Dealer Phone : {dealer_phone}')
#         print(f'Lien : {str(img_link)[str(img_link).index("data-src")+10:]}')
#         print("======================================================================")

# %%
data = get_data(url)

# %%
data
# Out:
#                                         Nom      Prix     Dealer Phone  \
# 0   2024 Mercedes-Benz C-Class C 300 4MATIC   $58,355  +1-417-283-4088
# 1   2024 Mercedes-Benz GLC 300 4MATIC Coupe   $59,995  +1-888-231-8049
# 2    2023 Mercedes-Benz CLS 450 Base 4MATIC   $83,140  +1-714-485-4670
# 3           2024 Mercedes-Benz AMG GLE 63 S  $133,685  +1-888-567-6576
# 4          2023 Mercedes-Benz E-Class E 350   $64,770  +1-866-604-1242
# 5    2023 Mercedes-Benz GLC 300 Base 4MATIC   $61,665  +1-888-352-6667
# 6    2023 Mercedes-Benz GLC 300 Base 4MATIC   $51,045  +1-417-283-4088
# 7    2024 Mercedes-Benz GLE 350 Base 4MATIC   $76,665  +1-877-857-0684
# 8   2023 Mercedes-Benz S-Class S 500 4MATIC  $122,735  +1-888-752-8814
# 9        2024 Mercedes-Benz AMG G 63 4MATIC  $212,670  +1-866-984-5567
# 10          2024 Mercedes-Benz S-Class Base  $134,305  +1-888-337-5745
# 11           2022 Mercedes-Benz Metris Base   $90,096  +1-866-475-0263
# 12  2024 Mercedes-Benz S-Class S 580 4MATIC  $142,795  +1-888-497-1614
# 13  2024 Mercedes-Benz S-Class S 580 4MATIC  $138,460  +1-888-604-1276
# 14         2024 Mercedes-Benz C-Class C 300   $49,185  +1-866-604-1242
# 15         2023 Mercedes-Benz E-Class E 450   $85,295  +1-678-413-5111
# 16   2024 Mercedes-Benz GLS 580 Base 4MATIC  $124,460  +1-847-859-0517
# 17   2024 Mercedes-Benz GLE 350 Base 4MATIC   $70,165  +1-888-752-8814
# 18          2024 Mercedes-Benz AMG GT 43 43  $118,590  +1-888-434-9416
# 19         2023 Mercedes-Benz E-Class E 450   $84,170  +1-866-475-0263
#
#                          Dealer Name         trims          makes  \
# 0             Elite Automotive Group  c_300_4matic  mercedes_benz
# 1    Kunes Mercedes-Benz of Sycamore  4matic_coupe  mercedes_benz
# 2           Mercedes-Benz of Anaheim   base_4matic  mercedes_benz
# 3      Mercedes-Benz of White Plains             s  mercedes_benz
# 4     Mercedes-Benz of Coconut Creek         e_350  mercedes_benz
# 5   Mercedes-Benz of Fort Lauderdale   base_4matic  mercedes_benz
# 6             Elite Automotive Group   base_4matic  mercedes_benz
# 7               Sears Imported Autos   base_4matic  mercedes_benz
# 8                    Star Motor Cars  s_500_4matic  mercedes_benz
# 9     Mercedes-Benz of Stevens Creek        4matic  mercedes_benz
# 10         Mercedes-Benz of Bellevue          base  mercedes_benz
# 11         Mercedes-Benz of Marietta          base  mercedes_benz
# 12           Mercedes-Benz of Denver  s_580_4matic  mercedes_benz
# 13         Mercedes-Benz of Westmont  s_580_4matic  mercedes_benz
# 14    Mercedes-Benz of Coconut Creek         c_300  mercedes_benz
# 15    Mercedes-Benz of Atlanta South         e_450  mercedes_benz
# 16       Loeber Motors Mercedes-Benz   base_4matic  mercedes_benz
# 17                   Star Motor Cars   base_4matic  mercedes_benz
# 18            Mercedes-Benz of Plano            43  mercedes_benz
# 19         Mercedes-Benz of Marietta         e_450  mercedes_benz
#
#    customer_ids stock_types model_years      models  sponsoreds   msrps  \
# 0       5379624         new        2024     c_class       False   58355
# 1       6051417         new        2024     glc_300       False   63260
# 2       6060959         new        2023     cls_450       False    None
# 3        154717         new        2024  amg_gle_63       False  133685
# 4        204368         new        2023     e_class       False   64770
# 5         11752         new        2023     glc_300       False   61665
# 6       5379624         new        2023     glc_300       False   51045
# 7         17466         new        2024     gle_350       False   76665
# 8        147550         new        2023     s_class       False    None
# 9         25758         new        2024    amg_g_63       False  212670
# 10       158589         new        2024     s_class       False  134305
# 11      5363861         new        2022      metris       False    None
# 12      5243849         new        2024     s_class       False  142795
# 13          325         new        2024     s_class       False  138460
# 14       204368         new        2024     c_class       False   49185
# 15      6033520         new        2023     e_class       False   85295
# 16      6035550         new        2024     gls_580       False  124460
# 17       147550         new        2024     gle_350       False    None
# 18        21711         new        2024   amg_gt_43       False  118590
# 19      5363861         new        2023     e_class       False   84170
#
#    sponsored_types  prices     bodystyles  results_page_numbers  \
# 0         standard   58355          sedan                     1
# 1         standard   59995            suv                     1
# 2         standard   83140          sedan                     1
# 3         standard  133685            suv                     1
# 4         standard   64770          sedan                     1
# 5         standard   61665            suv                     1
# 6         standard   51045            suv                     1
# 7         standard   76665            suv                     1
# 8         standard  122735          sedan                     1
# 9         standard  212670            suv                     1
# 10        standard  134305          sedan                     1
# 11        standard   90096  passenger_van                     1
# 12        standard  142795          sedan                     1
# 13        standard  138460          sedan                     1
# 14        standard   49185          sedan                     1
# 15        standard   85295    convertible                     1
# 16        standard  124460            suv                     1
# 17        standard   70165            suv                     1
# 18        standard  118590      hatchback                     1
# 19        standard   84170    convertible                     1
#
#     cpo_indicators  vertical_positions Rating
# 0            False                   2      -
# 1            False                   3      -
# 2            False                   4    4.8
# 3            False                   5    4.3
# 4            False                   6    4.6
# 5            False                   7    4.5
# 6            False                   8      -
# 7            False                   9    4.9
# 8            False                  10    4.8
# 9            False                  11    4.5
# 10           False                  12    4.6
# 11           False                  13    4.6
# 12           False                  14    4.4
# 13           False                  15    4.6
# 14           False                  16    4.6
# 15           False                  17    3.9
# 16           False                  18      -
# 17           False                  19    4.8
# 18           False                  20    4.7
# 19           False                  21    4.6

# %%
def get_data_bypage(size,nb_pages):
    """Cette fonction prend en paramètres un nombre données de pages à investiguer 
    et renvoie un dataframe contenant les différentes informations"""
    # Initialisation d'un nouveau dataframe
    final_data = pd.DataFrame(columns= ["Nom","Prix","Dealer Phone","Dealer Name","trims","makes","customer_ids","stock_types","model_years" ,"models" ,"sponsoreds" ,"msrps" ,"sponsored_types","prices" ,"bodystyles" ,"results_page_numbers" ,"cpo_indicators" ,"vertical_positions" ,"Lien"])
    for p in range(1,nb_pages+1) :
        # Url type selon le numéro de la page
        url_type = f"https://www.cars.com/shopping/results/?makes[]=mercedes_benz&maximum_distance=30&models[]=&page={p}&page_size={size}&stock_type=all&zip=%27"
        # Rechercher les informations sur la page
        data_find = get_data(url_type)
        # Ajouter les informations trouvées au dataframe initié au début
        final_data = pd.concat([final_data,data_find], axis=0)
        # Réinitialiser les index du dataframe
        final_data = final_data.reset_index(drop=True)
    return final_data

# %%
data = get_data_bypage(100,20)

# %%
data
# Out:
#                                           Nom      Prix     Dealer Phone  \
# 0             2023 Mercedes-Benz GLC 300 Base   $50,350  +1-888-287-1464
# 1           2023 Mercedes-Benz AMG SL 63 Base  $203,055  +1-661-578-6324
# 2           2024 Mercedes-Benz GLE 450 4MATIC   $75,545  +1-888-454-9101
# 3     2024 Mercedes-Benz S-Class S 580 4MATIC  $130,715  +1-678-413-5111
# 4             2023 Mercedes-Benz GLB 250 Base   $49,910  +1-760-268-9121
# ...                                       ...       ...              ...
# 1993         2024 Mercedes-Benz C-Class C 300   $50,475  +1-888-258-6644
# 1994  2024 Mercedes-Benz Maybach S 580 4MATIC  $214,700  +1-516-986-2613
# 1995   2013 Mercedes-Benz C-Class C 350 Sport   $12,511  +1-863-223-4576
# 1996       2023 Mercedes-Benz AMG GLB 35 Base   $49,750  +1-855-268-4610
# 1997  2023 Mercedes-Benz E-Class E 350 4MATIC   $68,770  +1-203-902-3814
#
#                          Dealer Name         trims          makes  \
# 0                   House of Imports          base  mercedes_benz
# 1       Mercedes-Benz of Bakersfield          base  mercedes_benz
# 2       Mercedes-Benz of Hunt Valley        4matic  mercedes_benz
# 3     Mercedes-Benz of Atlanta South  s_580_4matic  mercedes_benz
# 4          Mercedes-Benz of Carlsbad          base  mercedes_benz
# ...                              ...           ...            ...
# 1993        Mercedes-Benz of Orlando         c_300  mercedes_benz
# 1994                   Rallye Motors        4matic  mercedes_benz
# 1995                  Sebring Toyota   c_350_sport  mercedes_benz
# 1996   Mercedes-Benz of Owings Mills          base  mercedes_benz
# 1997    Mercedes-Benz of North Haven  e_350_4matic  mercedes_benz
#
#      customer_ids stock_types model_years         models sponsoreds   msrps  \
# 0            2904         new        2023        glc_300      False   50350
# 1          198646         new        2023      amg_sl_63      False  203055
# 2         2213560         new        2024        gle_450      False   75545
# 3         6033520         new        2024        s_class      False  130715
# 4           24741         new        2023        glb_250      False    None
# ...           ...         ...         ...            ...        ...     ...
# 1993       102491         new        2024        c_class      False   50475
# 1994         5691         new        2024  maybach_s_580      False  214700
# 1995      6059349        used        2013        c_class      False    None
# 1996      5257377        used        2023     amg_glb_35      False    None
# 1997       107395         new        2023        e_class      False   68770
#
#      sponsored_types    prices   bodystyles results_page_numbers  \
# 0           standard     50350          suv                    1
# 1           standard    203055  convertible                    1
# 2           standard     75545          suv                    1
# 3           standard    130715        sedan                    1
# 4           standard     49910          suv                    1
# ...              ...       ...          ...                  ...
# 1993        standard   50475.0        sedan                    1
# 1994        standard  214700.0        sedan                    1
# 1995        standard   12511.0        sedan                    1
# 1996        standard   49750.0          suv                    1
# 1997        standard   68770.0        sedan                    1
#
#      cpo_indicators vertical_positions Lien Rating
# 0             False                  2  NaN    4.8
# 1             False                  3  NaN      -
# 2             False                  4  NaN    4.7
# 3             False                  5  NaN    3.9
# 4             False                  6  NaN      -
# ...             ...                ...  ...    ...
# 1993          False                 97  NaN    4.7
# 1994          False                 98  NaN    4.8
# 1995          False                 99  NaN      -
# 1996           True                100  NaN    4.9
# 1997          False                101  NaN    4.7
#
# [1998 rows x 20 columns]

# %%
data.columns
# Out:
# Index(['Nom', 'Prix', 'Dealer Phone', 'Dealer Name', 'trims', 'makes',
#        'customer_ids', 'stock_types', 'model_years', 'models', 'sponsoreds',
#        'msrps', 'sponsored_types', 'prices', 'bodystyles',
#        'results_page_numbers', 'cpo_indicators', 'vertical_positions', 'Lien',
#        'Rating'],
#       dtype='object')
